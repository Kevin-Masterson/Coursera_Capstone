# %%
#conda install -c anaconda openpyxl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import xlrd 
import numpy as np

# %%
file = r'C:\Users\Kevin\Desktop\projects\Coursera_Capstone\Neighorhood_Indicators_CoreDataDownload_2020-06-30.xlsx'
nydata = pd.read_excel(file, sheet_name='Data', index_col=[0])
nydata.head()
# Out:
#           Region Display    Region Name Region Type  Year  adlt_incar_rt  \
# Region ID
# 606                  NYC  New York City        City  2000         1340.7
# 606                  NYC  New York City        City  2001            NaN
# 606                  NYC  New York City        City  2002            NaN
# 606                  NYC  New York City        City  2003            NaN
# 606                  NYC  New York City        City  2004            NaN
#
#            afford_le030_rct  afford_le080_rct  afford_le120_rct  crime_all_rt  \
# Region ID
# 606                     NaN               NaN               NaN          23.1
# 606                     NaN               NaN               NaN          20.3
# 606                     NaN               NaN               NaN          19.3
# 606                     NaN               NaN               NaN          18.4
# 606                     NaN               NaN               NaN          17.7
#
#            crime_prop_rt  ...  unit_occ_own_pct  unit_occ_rent_sevcrowd_pct  \
# Region ID                 ...
# 606                 15.4  ...             0.302                         NaN
# 606                 13.6  ...               NaN                         NaN
# 606                 12.9  ...               NaN                         NaN
# 606                 12.4  ...               NaN                         NaN
# 606                 12.1  ...               NaN                         NaN
#
#            unit_vac_rent_pct  units_cert  volume_1f  volume_4f  volume_al  \
# Region ID
# 606                      NaN     13603.0    13586.0    13702.0    33454.0
# 606                      NaN     14289.0    13750.0    14158.0    34564.0
# 606                      NaN     15024.0    16917.0    17561.0    44909.0
# 606                      NaN     17192.0    15889.0    16806.0    44976.0
# 606                      NaN     19052.0    16643.0    17438.0    46585.0
#
#            volume_cn  volume_ot  voucher_pct
# Region ID
# 606           4842.0     1324.0          NaN
# 606           5281.0     1375.0          NaN
# 606           8430.0     2001.0          NaN
# 606          10421.0     1860.0          NaN
# 606          10650.0     1854.0          NaN
#
# [5 rows x 120 columns]

# %%
pop = nydata[['Region Display', 'Year','pop_num']]
Queenspop = pop.loc[pop['Region Display'] == 'QN']
Bronxpop = pop.loc[pop['Region Display'] == 'BX']
Queenspop.plot('Year', kind='line')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
pop = nydata[['Region Display', 'Year','pop_num']]
Queenspop = pop.loc[pop['Region Display'] == 'QN']
Queenspop.dropna(inplace=True)
Bronxpop = pop.loc[pop['Region Display'] == 'BX']
Bronxpop.dropna(inplace=True)
# Out:
# <ipython-input-72-c25884b886ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bronxpop.dropna(inplace=True)
#           Region Display  Year    pop_num
# Region ID
# 602                   BX  2000  1327690.0
# 602                   BX  2005  1309640.0
# 602                   BX  2006  1361470.0
# 602                   BX  2007  1373660.0
# 602                   BX  2008  1391900.0
# 602                   BX  2009  1397290.0
# 602                   BX  2010  1386660.0
# 602                   BX  2011  1392000.0
# 602                   BX  2012  1408470.0
# 602                   BX  2013  1418730.0
# 602                   BX  2014  1438160.0
# 602                   BX  2015  1455440.0
# 602                   BX  2016  1455720.0
# 602                   BX  2017  1471160.0
# 602                   BX  2018  1432130.0

# %%
pop = nydata[['Region Display', 'Year','pop_num']]
Queenspop = pop.loc[pop['Region Display'] == 'QN']
Queenspop.dropna(inplace=True)
Bronxpop = pop.loc[pop['Region Display'] == 'BX']
Bronxpop.dropna(inplace=True)
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
Queenspop.plot('Year', kind='line', color='b')
plt.title("Queens Population")
plt.ylabel('Population per million')
Bronxpop.plot('Year', kind='line', color='r')
plt.title("Bronx Population")
plt.ylabel('Population per million')
# Out:
# Text(0, 0.5, 'Population per million')

# %%
x = Queenspop[['Year']]

y1 = Queenspop[['pop_num']]
y2 = Bronxpop[['pop_num']]

fig, axes = plt.subplots(nrows=1, ncols=2)
fig.suptitle('Population')
ax0, ax1  = axes.flatten()

ax0.plot(x, y1, color='b', label='Queens')
ax0.legend(prop={'size': 10})
ax0.set_ylabel('Population per million')
ax0.set_title('Queens pop')

ax1.plot(x, y2, color='r', label='Bronx')
ax1.legend(prop={'size': 10})
ax1.set_title('Bronx pop')

plt.show()

# %%
rentburden = nydata[['Region Display', 'Region Name', 'Region Type', 'Year','rburden_mod_ami_81_120', 'rburden_mod_ami_le80','rburden_sev_ami_81_120', 'rburden_sev_ami_le80']]
rentburden.head(100)
# Out:
#           Region Display    Region Name Region Type       Year  \
# Region ID
# 606                  NYC  New York City        City       2000
# 606                  NYC  New York City        City       2001
# 606                  NYC  New York City        City       2002
# 606                  NYC  New York City        City       2003
# 606                  NYC  New York City        City       2004
# ...                  ...            ...         ...        ...
# 603                   BK       Brooklyn     Borough       2002
# 603                   BK       Brooklyn     Borough       2003
# 603                   BK       Brooklyn     Borough       2004
# 603                   BK       Brooklyn     Borough       2005
# 603                   BK       Brooklyn     Borough  2005-2009
#
#            rburden_mod_ami_81_120  rburden_mod_ami_le80  \
# Region ID
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# ...                           ...                   ...
# 603                           NaN                   NaN
# 603                           NaN                   NaN
# 603                           NaN                   NaN
# 603                           NaN                   NaN
# 603                          0.15                 0.309
#
#            rburden_sev_ami_81_120  rburden_sev_ami_le80
# Region ID
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# 606                           NaN                   NaN
# ...                           ...                   ...
# 603                           NaN                   NaN
# 603                           NaN                   NaN
# 603                           NaN                   NaN
# 603                           NaN                   NaN
# 603                         0.009                 0.425
#
# [100 rows x 8 columns]

# %%
# rename the columns so we can make more sense of them
#df.rename(columns={"A": "a", "B": "b", "C": "c"}, errors="raise")
#rentburden.rename(columns={"rburden_mod_ami_81_120": ""})

# %% [markdown]
# Seeing that these columns headings are note very intuative, and the explainations are long, The descritpion of each is extracted from the data source here:
#
# rburden_mod_ami_81_120:	The share of moderate-income renter households whose gross rent made up at least 30 percent of their monthly pre-tax income.
# rburden_mod_ami_le80:	The share of low-income renter households whose gross rent made up at least 30 percent of their monthly pre-tax income.
# rburden_sev_ami_81_120:	The share of moderate-income renter households whose gross rent made up at least 50 percent of their monthly pre-tax income.
# rburden_sev_ami_le80:	The share of low-income renter households whose gross rent made up at least 50 percent of their monthly pre-tax income.

# %%
Queens_rburden = rentburden.loc[rentburden['Region Display'] == 'QN']
Queens_rburden.dropna(inplace=True)
Queens_rburden.head(100)
# Out:
# <ipython-input-6-b7103f71cdc2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Queens_rburden.dropna(inplace=True)
#           Region Display Region Name Region Type       Year  \
# Region ID
# 604                   QN      Queens     Borough  2005-2009
# 604                   QN      Queens     Borough  2006-2010
# 604                   QN      Queens     Borough  2007-2011
# 604                   QN      Queens     Borough  2008-2012
# 604                   QN      Queens     Borough  2009-2013
# 604                   QN      Queens     Borough  2010-2014
# 604                   QN      Queens     Borough  2011-2015
# 604                   QN      Queens     Borough  2012-2016
# 604                   QN      Queens     Borough  2013-2017
# 604                   QN      Queens     Borough  2014-2018
#
#            rburden_mod_ami_81_120  rburden_mod_ami_le80  \
# Region ID
# 604                         0.169                 0.347
# 604                         0.172                 0.339
# 604                         0.185                 0.334
# 604                         0.196                 0.323
# 604                         0.187                 0.323
# 604                         0.226                 0.316
# 604                         0.212                 0.317
# 604                         0.186                 0.324
# 604                         0.186                 0.324
# 604                         0.161                 0.338
#
#            rburden_sev_ami_81_120  rburden_sev_ami_le80
# Region ID
# 604                         0.009                 0.456
# 604                         0.007                 0.462
# 604                         0.008                 0.473
# 604                         0.009                 0.493
# 604                         0.007                 0.496
# 604                         0.010                 0.524
# 604                         0.009                 0.516
# 604                         0.008                 0.507
# 604                         0.008                 0.507
# 604                         0.006                 0.465

# %%
Bronx_rburden = rentburden.loc[rentburden['Region Display'] == 'BX']
Bronx_rburden.dropna(inplace=True)
Bronx_rburden.head(100)
# Out:
# <ipython-input-8-5528a80e3b53>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bronx_rburden.dropna(inplace=True)
#           Region Display Region Name Region Type       Year  \
# Region ID
# 602                   BX       Bronx     Borough  2005-2009
# 602                   BX       Bronx     Borough  2006-2010
# 602                   BX       Bronx     Borough  2007-2011
# 602                   BX       Bronx     Borough  2008-2012
# 602                   BX       Bronx     Borough  2009-2013
# 602                   BX       Bronx     Borough  2010-2014
# 602                   BX       Bronx     Borough  2011-2015
# 602                   BX       Bronx     Borough  2012-2016
# 602                   BX       Bronx     Borough  2013-2017
# 602                   BX       Bronx     Borough  2014-2018
#
#            rburden_mod_ami_81_120  rburden_mod_ami_le80  \
# Region ID
# 602                         0.052                 0.283
# 602                         0.058                 0.287
# 602                         0.065                 0.294
# 602                         0.080                 0.298
# 602                         0.080                 0.304
# 602                         0.100                 0.313
# 602                         0.087                 0.311
# 602                         0.084                 0.309
# 602                         0.084                 0.309
# 602                         0.053                 0.304
#
#            rburden_sev_ami_81_120  rburden_sev_ami_le80
# Region ID
# 602                         0.004                 0.410
# 602                         0.003                 0.408
# 602                         0.004                 0.420
# 602                         0.003                 0.430
# 602                         0.004                 0.427
# 602                         0.005                 0.444
# 602                         0.005                 0.445
# 602                         0.002                 0.434
# 602                         0.002                 0.434
# 602                         0.001                 0.426

# %%
Queensrbplt = Queens_rburden[['Year','rburden_mod_ami_81_120', 'rburden_mod_ami_le80','rburden_sev_ami_81_120', 'rburden_sev_ami_le80']]
Queensrbplt.reset_index(drop=True, inplace=True)
Queensrbplt
# Out:
#         Year  rburden_mod_ami_81_120  rburden_mod_ami_le80  \
# 0  2005-2009                   0.169                 0.347
# 1  2006-2010                   0.172                 0.339
# 2  2007-2011                   0.185                 0.334
# 3  2008-2012                   0.196                 0.323
# 4  2009-2013                   0.187                 0.323
# 5  2010-2014                   0.226                 0.316
# 6  2011-2015                   0.212                 0.317
# 7  2012-2016                   0.186                 0.324
# 8  2013-2017                   0.186                 0.324
# 9  2014-2018                   0.161                 0.338
#
#    rburden_sev_ami_81_120  rburden_sev_ami_le80
# 0                   0.009                 0.456
# 1                   0.007                 0.462
# 2                   0.008                 0.473
# 3                   0.009                 0.493
# 4                   0.007                 0.496
# 5                   0.010                 0.524
# 6                   0.009                 0.516
# 7                   0.008                 0.507
# 8                   0.008                 0.507
# 9                   0.006                 0.465

# %%
Queensrbplt.plot('Year', kind='area', alpha=0.35, figsize=(20, 10))

plt.title('Rent Burden Queens')
plt.ylabel('% of population spending X amount of income')
plt.xlabel('Years')

plt.show()

# %%
Queensrbplt.plot('Year', kind='line', alpha=0.35, figsize=(10, 8)) 

plt.title('Rent Burden Queens')
plt.ylabel('% of population spending X amount of income')
plt.xlabel('Years')

plt.show()

# %%
Bronx_rburden = Bronx_rburden[['Year','rburden_mod_ami_81_120', 'rburden_mod_ami_le80','rburden_sev_ami_81_120', 'rburden_sev_ami_le80']]
Bronx_rburden.plot('Year', kind='line', alpha=0.35, figsize=(10, 8))

plt.title('Rent Burden Bronx')
plt.ylabel('% of population spending X amount of income')
plt.xlabel('Years')

plt.show()

# %%
#To help view the labels easier we will use the year end year instead of the hyphenated name 
new = Bronx_rburden['Year'].str.split("-", n = 1, expand = True) 
Bronx_rburden["yearend"] = new[1]

# %%
x = np.arange(len(Bronx_rburden['Year']))  # the label locations
width = 0.15  # the width of the bars

w = width
bar1 = x
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]
bar4 = [i+w for i in bar3]

fig, ax = plt.subplots()
#rects1 = ax.bar(x - width/4, Bronx_rburden['rburden_mod_ami_81_120'], width, label='Mod120')
rects1 = ax.bar(x - width/2.5, Bronx_rburden['rburden_mod_ami_81_120'], width, label='Mod120')
rects2 = ax.bar(bar2, Bronx_rburden['rburden_mod_ami_le80'], width, label='Mod80')
rects3 = ax.bar(bar3, Bronx_rburden['rburden_sev_ami_81_120'], width, label='Sev120')
rects4 = ax.bar(bar4, Bronx_rburden['rburden_sev_ami_le80'], width, label='Sev80')



# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('% of population spending X amount of income')
ax.set_title('Rent Burden Bronx')
ax.set_xticks(bar1 + w )
ax.set_xticklabels(Bronx_rburden["yearend"])
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{0:.1%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

fig.tight_layout()

plt.show()

# %% [markdown]
# # Queens Bar cahrt

# %%
new = Queens_rburden['Year'].str.split("-", n = 1, expand = True) 
Queens_rburden["yearend"] = new[1]

#Queensrbplt

x = np.arange(len(Queens_rburden['Year']))  # the label locations
width = 0.15  # the width of the bars

w = width
bar1 = x
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]
bar4 = [i+w for i in bar3]

fig, ax = plt.subplots()
#rects1 = ax.bar(x - width/4, Bronx_rburden['rburden_mod_ami_81_120'], width, label='Mod120')
rects1 = ax.bar(x - width/2.5, Queens_rburden['rburden_mod_ami_81_120'], width, label='Mod120')
rects2 = ax.bar(bar2, Queens_rburden['rburden_mod_ami_le80'], width, label='Mod80')
rects3 = ax.bar(bar3, Queens_rburden['rburden_sev_ami_81_120'], width, label='Sev120')
rects4 = ax.bar(bar4, Queens_rburden['rburden_sev_ami_le80'], width, label='Sev80')



# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('% of population spending X amount of income')
ax.set_title('Rent Burden Queens')
ax.set_xticks(bar1 + w )
ax.set_xticklabels(Queens_rburden["yearend"])
ax.legend()


#def autolabel(rects):
#    """Attach a text label above each bar in *rects*, displaying its height."""
#    for rect in rects:
#        height = rect.get_height()
#        ax.annotate('{0:.1%}'.format(height),
#                    xy=(rect.get_x() + rect.get_width() / 2, height),
#                    xytext=(0, 3),  # 3 points vertical offset
#                    textcoords="offset points",
#                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)

fig.tight_layout()

plt.show()
# Out:
# <ipython-input-17-0fcfc74600fb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Queens_rburden["yearend"] = new[1]

# %% [markdown]
# ## Population data
# % population over 25 who have obtained a degree
#
# pop_edu_collp_pct: The percentage of the population aged 25 and older who have attained a bachelor's degree or higher.
# pop_edu_nohs_pct: The percentage of the population aged 25 and older who have not graduated from high school or received a GED.

# %%
edupop = nydata[['Region Display', 'Region Name', 'Region Type', 'Year','pop_edu_collp_pct', 'pop_edu_nohs_pct']]
Queensedupop = edupop.loc[edupop['Region Display'] == 'QN']
Bronxedupop = edupop.loc[edupop['Region Display'] == 'BX']

Queensedupop.dropna(inplace=True)
Bronxedupop.dropna(inplace=True)
# Out:
# <ipython-input-18-f911f604dd75>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Queensedupop.dropna(inplace=True)
# <ipython-input-18-f911f604dd75>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bronxedupop.dropna(inplace=True)

# %%
x = Queensedupop[['Year']]

y1 = Queensedupop[['pop_edu_collp_pct', 'pop_edu_nohs_pct']]
y2 = Bronxedupop[['pop_edu_collp_pct', 'pop_edu_nohs_pct']]

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Education Levels')
ax1.plot(x, y1)
ax1.set_title('Queensedupop')
ax2.plot(x, y2)
ax2.set_title('Bronxedupop')
ax1.legend()
ax2.legend()

fig.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
x = Queensedupop[['Year']]

y1 = Queensedupop[['pop_edu_collp_pct', 'pop_edu_nohs_pct']]
y2 = Bronxedupop[['pop_edu_collp_pct', 'pop_edu_nohs_pct']]

fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Population Education Data')
ax1.plot(x, y1)
ax1.set_title('Queens Edu Pop')
ax2.plot(x, y2)
ax2.set_title('Bronx Edu Pop')
plt.ylabel('% of population at age 25')
plt.xlabel('Year')

from matplotlib.patches import Patch
pa1 = Patch(facecolor='orange', edgecolor='black')
pa2 = Patch(facecolor='blue', edgecolor='black')

ax1.legend(handles=[pa1, pa2],
          labels=['No Edu  ', 'College Edu'],
          ncol=4, handletextpad=0.5, handlelength=1.0, columnspacing=-0.5, fontsize=16)
ax2.legend(handles=[pa1, pa2 ],
          labels=['No Edu  ',  'College Edu'],
          ncol=2, handletextpad=0.5, handlelength=1.0, columnspacing=-0.5, loc='center left', fontsize=16)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Income data
#
# hh_inc_med_adj: The median household's total income of all members of the household aged 15 years or older.
# hh_inc_own_med_adj: The median owner-occupied household's total income of all members of the household aged 15 years or older.
# hh_inc_rent_med_adj: The median renter household's total income of all members of the household aged 15 years or older.

# %%
incomedata = nydata[['Region Display', 'Region Name', 'Region Type', 'Year','hh_inc_med_adj', 'hh_inc_own_med_adj','hh_inc_rent_med_adj']]
Qincome = incomedata.loc[incomedata['Region Display'] == 'QN']
Bincome = incomedata.loc[incomedata['Region Display'] == 'BX']
Qincome.dropna(inplace=True)
Bincome.dropna(inplace=True)
# Out:
# <ipython-input-21-fccf63089ca2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Qincome.dropna(inplace=True)
# <ipython-input-21-fccf63089ca2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bincome.dropna(inplace=True)

# %%
Qincome.plot('Year', kind='line', alpha=0.35, figsize=(10, 8))
plt.title('Queens Income $$$')
plt.ylabel('$$$')
plt.xlabel('Years')
plt.show()


Bincome.plot('Year', kind='line', alpha=0.35, figsize=(10, 8))
plt.title('Bronx Income $$$')
plt.ylabel('$$$')
plt.xlabel('Years')
plt.show()

plt.show()

# %%
income_diversity = nydata[['Region Display', 'Year','income_diversity_ratio']]
income_diversity.dropna(inplace=True)
QueensDiversity = income_diversity.loc[income_diversity['Region Display'] == 'QN']
BronxDiversity = income_diversity.loc[income_diversity['Region Display'] == 'BX']
# Out:
# <ipython-input-24-8db4546a7f18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income_diversity.dropna(inplace=True)

# %%
QueensDiversity.plot('Year', kind='line')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
BronxDiversity.plot('Year', kind='line')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Crime might not seem a necessary indicator of where we will set our business but it will be interesting if the analysis was close..

# %%
crime = nydata[['Region Display', 'Year', 'pfn_fam14condo_rate','adlt_incar_rt']]
QueensCrime = crime.loc[crime['Region Display'] == 'QN']
QueensCrime.dropna(inplace=True)
BronxCrime = crime.loc[crime['Region Display'] == 'BX']
BronxCrime.dropna(inplace=True)
# Out:
# <ipython-input-54-377b6f510118>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   QueensCrime.dropna(inplace=True)
# <ipython-input-54-377b6f510118>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BronxCrime.dropna(inplace=True)

# %%
QueensCrime.head(100)
# Out:
#           Region Display  Year  pfn_fam14condo_rate  adlt_incar_rt
# Region ID
# 604                   QN  2011                105.6          470.6
# 604                   QN  2012                100.7          442.8
# 604                   QN  2013                 90.3          473.5
# 604                   QN  2014                 54.1          476.9

# %%
BronxCrime
# Out:
#           Region Display  Year  pfn_fam14condo_rate  adlt_incar_rt
# Region ID
# 602                   BX  2011                119.2          890.9
# 602                   BX  2012                118.5          942.0
# 602                   BX  2013                111.4          950.3
# 602                   BX  2014                 71.2          829.4
